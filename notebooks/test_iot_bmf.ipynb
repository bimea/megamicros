# %% [markdown]
# # Test

# %%
import numpy as np
import matplotlib.pyplot as plt
import json
from mpl_toolkits.mplot3d import Axes3D
from IPython import display
from megamicros_tools.log import log
import megamicros_tools.mqtt as mqtt

# %% [markdown]
# ## Start MQTT

# %%
client = mqtt.MqttClient( host='mqtt.bimea.tech', name='test_iot_bmf' )
if client.is_connected():
    print( "Connected to MQTT broker" )
else:
    print( "Failed to connect to MQTT broker" )
# Out:
# 2024-06-13 18:56:57,186 [ERROR]: in megamicros_tools.log (mqtt.py:100): MQTT broker connection failed: timed out
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 client = mqtt.MqttClient( host='mqtt.bimea.tech', name='test_iot_bmf' )
#       2 if client.is_connected():
#       3     print( "Connected to MQTT broker" )
#
# File ~/Documents/Dev/Bimea/megamicros/venv/lib/python3.10/site-packages/megamicros_tools/mqtt.py:95, in MqttClient.__init__(self, host, port, name)
#      93     self.__client.user_data_set( self )
#      94     self.__client.on_connect = on_connect
# ---> 95     self.__client.connect( host=host, port=port, keepalive=60, bind_address="" )
#      96     self.__connected = True
#      99 except Exception as e:
#
# ...

# %%
def on_message( client, userdata, msg):
    
    message = json.loads( msg.payload.decode() )

    report = None
    if 'content' in message and 'report' in message['content']:
        report = json.loads( message['content'] )['report']
    else:
        return
    
    BFE = report['BFE']
    mems_position = report['mems_position']
    locations_position = report['locations_position']
    sampling_frequency = report['sampling_frequency']
    frame_length = report['frame_length']
    max_energy_index = report['index']

    print( report )

    # print area locations and antenna 
    fig = plt.figure()
    ax = fig.add_subplot( 131, projection='3d' )
    ax.scatter( mems_position[:,0], mems_position[:,1], mems_position[:,2] )
    ax.scatter( locations_position[:,0], locations_position[:,1], locations_position[:,2] )
    ax = fig.add_subplot( 132, projection='3d' )
    ax.scatter( mems_position[:,0], mems_position[:,1], mems_position[:,2] )
    fig.show()

# %%
client.run( 'romille/mater/1/device/mu32/poc2-3/status', on_message )

# %%
mems_position = np.array( [
  [ 3.035, 3.8, 2.05 ],
  [ 3.03164, 3.83414, 2.05 ],
  [ 3.02168, 3.86697, 2.05 ],
  [ 3.00551, 3.89722, 2.05 ],
  [ 2.9837, 3.9237, 2.05 ],
  [ 2.95722, 3.94551, 2.05 ],
  [ 2.92697, 3.96168, 2.05 ],
  [ 2.89414, 3.97164, 2.05 ],
  [ 2.86, 3.975, 2.05 ],
  [ 2.82586, 3.97164, 2.05 ],
  [ 2.79303, 3.96168, 2.05 ],
  [ 2.76278, 3.94551, 2.05 ],
  [ 2.73626, 3.92374, 2.05 ],
  [ 2.71449, 3.89722, 2.05 ],
  [ 2.68836, 3.83414, 2.05 ],
  [ 2.685, 3.8, 2.05 ],
  [ 2.68836, 3.76586, 2.05 ],
  [ 2.69832, 3.73303, 2.05 ],
  [ 2.71449, 3.70278, 2.05 ],
  [ 2.73626, 3.67626, 2.05 ],
  [ 2.76278, 3.65449, 2.05 ],
  [ 2.79303, 3.63832, 2.05 ],
  [ 2.82586, 3.62836, 2.05 ],
  [ 2.86, 3.625,2.05 ],
  [ 2.89414, 3.62836, 2.05 ],
  [ 2.92697, 3.63832, 2.05 ],
  [ 2.95722, 3.65449, 2.05 ],
  [ 2.98374, 3.67626, 2.05 ],
  [ 3.00551, 3.70278, 2.05 ],
  [ 3.02168, 3.73303, 2.05 ],
  [ 3.03164, 3.76586, 2.05 ]
] )

mems_position2 = np.array( [
  [3.1088, 3.7755, 2 ],
  [3.09924, 3.72743, 2 ],
  [3.08048, 3.68215, 2 ],
  [3.05325, 3.6414, 2 ],
  [3.0186, 3.60675, 2 ],
  [2.97785, 3.57952, 2 ],
  [2.93257, 3.56076, 2 ],
  [2.8845, 3.5512, 2 ],
  [2.8355, 3.5512, 2 ],
  [2.78743, 3.56076, 2 ],
  [2.74215, 3.57952, 2 ],
  [2.7014, 3.60675, 2 ],
  [2.66675, 3.6414, 2 ],
  [2.63952, 3.68215, 2 ],
  [2.62076, 3.72743, 2 ],
  [2.6112, 3.7755, 2 ],
  [2.6112, 3.8245, 2 ],
  [2.62076, 3.87257, 2 ],
  [2.63952, 3.91785, 2 ],
  [2.66675, 3.9586, 2 ],
  [2.7014, 3.99325, 2 ],
  [2.74215, 4.02048, 2 ],
  [2.78743, 4.03924, 2 ],
  [2.8355, 4.0488, 2 ],
  [2.8845, 4.0488, 2 ],
  [2.93257, 4.03924, 2 ],
  [2.97785, 4.02048, 2 ],
  [3.0186, 3.99325, 2 ],
  [3.05325, 3.9586, 2 ],
  [3.08048, 3.91785, 2 ],
  [3.09924, 3.87257, 2 ],
  [3.1088, 3.8245, 2 ]
] )

print( mems_position )

# %%
locations = np.array( [
  [0.143, 0.19, 0.25 ],
  [0.143, 0.57, 0.25 ],
  [0.143, 0.95, 0.25 ],
  [0.143, 1.33, 0.25 ],
  [0.143, 1.71, 0.25 ],
  [0.143, 2.09, 0.25 ],
  [0.143, 2.47, 0.25 ],
  [0.143, 2.85, 0.25 ],
  [0.143, 3.23, 0.25 ],
  [0.143, 3.61, 0.25 ],
  [0.143, 3.99, 0.25 ],
  [0.143, 4.37, 0.25 ],
  [0.143, 4.75, 0.25 ],
  [0.143, 5.13, 0.25 ],
  [0.143, 5.51, 0.25 ],
  [0.143, 5.89, 0.25 ],
  [0.143, 6.27, 0.25 ],
  [0.143, 6.65, 0.25 ],
  [0.143, 7.03, 0.25 ],
  [0.143, 7.41, 0.25 ],
  [0.429, 0.19, 0.25 ],
  [0.429, 0.57, 0.25 ],
  [0.429, 0.95, 0.25 ],
  [0.429, 1.33, 0.25 ],
  [0.429, 1.71, 0.25 ],
  [0.429, 2.09, 0.25 ],
  [0.429, 2.47, 0.25 ],
  [0.429, 2.85, 0.25 ],
  [0.429, 3.23, 0.25 ],
  [0.429, 3.61, 0.25 ],
  [0.429, 3.99, 0.25 ],
  [0.429, 4.37, 0.25 ],
  [0.429, 4.75, 0.25 ],
  [0.429, 5.13, 0.25 ],
  [0.429, 5.51, 0.25 ],
  [0.429, 5.89, 0.25 ],
  [0.429, 6.27, 0.25 ],
  [0.429, 6.65, 0.25 ],
  [0.429, 7.03, 0.25 ],
  [0.429, 7.41, 0.25 ],
  [0.715, 0.19, 0.25 ],
  [0.715, 0.57, 0.25 ],
  [0.715, 0.95, 0.25 ],
  [0.715, 1.33, 0.25 ],
  [0.715, 1.71, 0.25 ],
  [0.715, 2.09, 0.25 ],
  [0.715, 2.47, 0.25 ],
  [0.715, 2.85, 0.25 ],
  [0.715, 3.23, 0.25 ],
  [0.715, 3.61, 0.25 ],
  [0.715, 3.99, 0.25 ],
  [0.715, 4.37, 0.25 ],
  [0.715, 4.75, 0.25 ],
  [0.715, 5.13, 0.25 ],
  [0.715, 5.51, 0.25 ],
  [0.715, 5.89, 0.25 ],
  [0.715, 6.27, 0.25 ],
  [0.715, 6.65, 0.25 ],
  [0.715, 7.03, 0.25 ],
  [0.715, 7.41, 0.25 ],
  [1.001, 0.19, 0.25 ],
  [1.001, 0.57, 0.25 ],
  [1.001, 0.95, 0.25 ],
  [1.001, 1.33, 0.25 ],
  [1.001, 1.71, 0.25 ],
  [1.001, 2.09, 0.25 ],
  [1.001, 2.47, 0.25 ],
  [1.001, 2.85, 0.25 ],
  [1.001, 3.23, 0.25 ],
  [1.001, 3.61, 0.25 ],
  [1.001, 3.99, 0.25 ],
  [1.001, 4.37, 0.25 ],
  [1.001, 4.75, 0.25 ],
  [1.001, 5.13, 0.25 ],
  [1.001, 5.51, 0.25 ],
  [1.001, 5.89, 0.25 ],
  [1.001, 6.27, 0.25 ],
  [1.001, 6.65, 0.25 ],
  [1.001, 7.03, 0.25 ],
  [1.001, 7.41, 0.25 ],
  [1.287, 0.19, 0.25 ],
  [1.287, 0.57, 0.25 ],
  [1.287, 0.95, 0.25 ],
  [1.287, 1.33, 0.25 ],
  [1.287, 1.71, 0.25 ],
  [1.287, 2.09, 0.25 ],
  [1.287, 2.47, 0.25 ],
  [1.287, 2.85, 0.25 ],
  [1.287, 3.23, 0.25 ],
  [1.287, 3.61, 0.25 ],
  [1.287, 3.99, 0.25 ],
  [1.287, 4.37, 0.25 ],
  [1.287, 4.75, 0.25 ],
  [1.287, 5.13, 0.25 ],
  [1.287, 5.51, 0.25 ],
  [1.287, 5.89, 0.25 ],
  [1.287, 6.27, 0.25 ],
  [1.287, 6.65, 0.25 ],
  [1.287, 7.03, 0.25 ],
  [1.287, 7.41, 0.25 ],
  [1.573, 0.19, 0.25 ],
  [1.573, 0.57, 0.25 ],
  [1.573, 0.95, 0.25 ],
  [1.573, 1.33, 0.25 ],
  [1.573, 1.71, 0.25 ],
  [1.573, 2.09, 0.25 ],
  [1.573, 2.47, 0.25 ],
  [1.573, 2.85, 0.25 ],
  [1.573, 3.23, 0.25 ],
  [1.573, 3.61, 0.25 ],
  [1.573, 3.99, 0.25 ],
  [1.573, 4.37, 0.25 ],
  [1.573, 4.75, 0.25 ],
  [1.573, 5.13, 0.25 ],
  [1.573, 5.51, 0.25 ],
  [1.573, 5.89, 0.25 ],
  [1.573, 6.27, 0.25 ],
  [1.573, 6.65, 0.25 ],
  [1.573, 7.03, 0.25 ],
  [1.573, 7.41, 0.25 ],
  [1.859, 0.19, 0.25 ],
  [1.859, 0.57, 0.25 ],
  [1.859, 0.95, 0.25 ],
  [1.859, 1.33, 0.25 ],
  [1.859, 1.71, 0.25 ],
  [1.859, 2.09, 0.25 ],
  [1.859, 2.47, 0.25 ],
  [1.859, 2.85, 0.25 ],
  [1.859, 3.23, 0.25 ],
  [1.859, 3.61, 0.25 ],
  [1.859, 3.99, 0.25 ],
  [1.859, 4.37, 0.25 ],
  [1.859, 4.75, 0.25 ],
  [1.859, 5.13, 0.25 ],
  [1.859, 5.51, 0.25 ],
  [1.859, 5.89, 0.25 ],
  [1.859, 6.27, 0.25 ],
  [1.859, 6.65, 0.25 ],
  [1.859, 7.03, 0.25 ],
  [1.859, 7.41, 0.25 ],
  [2.145, 0.19, 0.25 ],
  [2.145, 0.57, 0.25 ],
  [2.145, 0.95, 0.25 ],
  [2.145, 1.33, 0.25 ],
  [2.145, 1.71, 0.25 ],
  [2.145, 2.09, 0.25 ],
  [2.145, 2.47, 0.25 ],
  [2.145, 2.85, 0.25 ],
  [2.145, 3.23, 0.25 ],
  [2.145, 3.61, 0.25 ],
  [2.145, 3.99, 0.25 ],
  [2.145, 4.37, 0.25 ],
  [2.145, 4.75, 0.25 ],
  [2.145, 5.13, 0.25 ],
  [2.145, 5.51, 0.25 ],
  [2.145, 5.89, 0.25 ],
  [2.145, 6.27, 0.25 ],
  [2.145, 6.65, 0.25 ],
  [2.145, 7.03, 0.25 ],
  [2.145, 7.41, 0.25 ],
  [2.431, 0.19, 0.25 ],
  [2.431, 0.57, 0.25 ],
  [2.431, 0.95, 0.25 ],
  [2.431, 1.33, 0.25 ],
  [2.431, 1.71, 0.25 ],
  [2.431, 2.09, 0.25 ],
  [2.431, 2.47, 0.25 ],
  [2.431, 2.85, 0.25 ],
  [2.431, 3.23, 0.25 ],
  [2.431, 3.61, 0.25 ],
  [2.431, 3.99, 0.25 ],
  [2.431, 4.37, 0.25 ],
  [2.431, 4.75, 0.25 ],
  [2.431, 5.13, 0.25 ],
  [2.431, 5.51, 0.25 ],
  [2.431, 5.89, 0.25 ],
  [2.431, 6.27, 0.25 ],
  [2.431, 6.65, 0.25 ],
  [2.431, 7.03, 0.25 ],
  [2.431, 7.41, 0.25 ],
  [2.717, 0.19, 0.25 ],
  [2.717, 0.57, 0.25 ],
  [2.717, 0.95, 0.25 ],
  [2.717, 1.33, 0.25 ],
  [2.717, 1.71, 0.25 ],
  [2.717, 2.09, 0.25 ],
  [2.717, 2.47, 0.25 ],
  [2.717, 2.85, 0.25 ],
  [2.717, 3.23, 0.25 ],
  [2.717, 3.61, 0.25 ],
  [2.717, 3.99, 0.25 ],
  [2.717, 4.37, 0.25 ],
  [2.717, 4.75, 0.25 ],
  [2.717, 5.13, 0.25 ],
  [2.717, 5.51, 0.25 ],
  [2.717, 5.89, 0.25 ],
  [2.717, 6.27, 0.25 ],
  [2.717, 6.65, 0.25 ],
  [2.717, 7.03, 0.25 ],
  [2.717, 7.41, 0.25 ],
  [3.003, 0.19, 0.25 ],
  [3.003, 0.57, 0.25 ],
  [3.003, 0.95, 0.25 ],
  [3.003, 1.33, 0.25 ],
  [3.003, 1.71, 0.25 ],
  [3.003, 2.09, 0.25 ],
  [3.003, 2.47, 0.25 ],
  [3.003, 2.85, 0.25 ],
  [3.003, 3.23, 0.25 ],
  [3.003, 3.61, 0.25 ],
  [3.003, 3.99, 0.25 ],
  [3.003, 4.37, 0.25 ],
  [3.003, 4.75, 0.25 ],
  [3.003, 5.13, 0.25 ],
  [3.003, 5.51, 0.25 ],
  [3.003, 5.89, 0.25 ],
  [3.003, 6.27, 0.25 ],
  [3.003, 6.65, 0.25 ],
  [3.003, 7.03, 0.25 ],
  [3.003, 7.41, 0.25 ],
  [3.289, 0.19, 0.25 ],
  [3.289, 0.57, 0.25 ],
  [3.289, 0.95, 0.25 ],
  [3.289, 1.33, 0.25 ],
  [3.289, 1.71, 0.25 ],
  [3.289, 2.09, 0.25 ],
  [3.289, 2.47, 0.25 ],
  [3.289, 2.85, 0.25 ],
  [3.289, 3.23, 0.25 ],
  [3.289, 3.61, 0.25 ],
  [3.289, 3.99, 0.25 ],
  [3.289, 4.37, 0.25 ],
  [3.289, 4.75, 0.25 ],
  [3.289, 5.13, 0.25 ],
  [3.289, 5.51, 0.25 ],
  [3.289, 5.89, 0.25 ],
  [3.289, 6.27, 0.25 ],
  [3.289, 6.65, 0.25 ],
  [3.289, 7.03, 0.25 ],
  [3.289, 7.41, 0.25 ],
  [3.575, 0.19, 0.25 ],
  [3.575, 0.57, 0.25 ],
  [3.575, 0.95, 0.25 ],
  [3.575, 1.33, 0.25 ],
  [3.575, 1.71, 0.25 ],
  [3.575, 2.09, 0.25 ],
  [3.575, 2.47, 0.25 ],
  [3.575, 2.85, 0.25 ],
  [3.575, 3.23, 0.25 ],
  [3.575, 3.61, 0.25 ],
  [3.575, 3.99, 0.25 ],
  [3.575, 4.37, 0.25 ],
  [3.575, 4.75, 0.25 ],
  [3.575, 5.13, 0.25 ],
  [3.575, 5.51, 0.25 ],
  [3.575, 5.89, 0.25 ],
  [3.575, 6.27, 0.25 ],
  [3.575, 6.65, 0.25 ],
  [3.575, 7.03, 0.25 ],
  [3.575, 7.41, 0.25 ],
  [3.861, 0.19, 0.25 ],
  [3.861, 0.57, 0.25 ],
  [3.861, 0.95, 0.25 ],
  [3.861, 1.33, 0.25 ],
  [3.861, 1.71, 0.25 ],
  [3.861, 2.09, 0.25 ],
  [3.861, 2.47, 0.25 ],
  [3.861, 2.85, 0.25 ],
  [3.861, 3.23, 0.25 ],
  [3.861, 3.61, 0.25 ],
  [3.861, 3.99, 0.25 ],
  [3.861, 4.37, 0.25 ],
  [3.861, 4.75, 0.25 ],
  [3.861, 5.13, 0.25 ],
  [3.861, 5.51, 0.25 ],
  [3.861, 5.89, 0.25 ],
  [3.861, 6.27, 0.25 ],
  [3.861, 6.65, 0.25 ],
  [3.861, 7.03, 0.25 ],
  [3.861, 7.41, 0.25 ],
  [4.147, 0.19, 0.25 ],
  [4.147, 0.57, 0.25 ],
  [4.147, 0.95, 0.25 ],
  [4.147, 1.33, 0.25 ],
  [4.147, 1.71, 0.25 ],
  [4.147, 2.09, 0.25 ],
  [4.147, 2.47, 0.25 ],
  [4.147, 2.85, 0.25 ],
  [4.147, 3.23, 0.25 ],
  [4.147, 3.61, 0.25 ],
  [4.147, 3.99, 0.25 ],
  [4.147, 4.37, 0.25 ],
  [4.147, 4.75, 0.25 ],
  [4.147, 5.13, 0.25 ],
  [4.147, 5.51, 0.25 ],
  [4.147, 5.89, 0.25 ],
  [4.147, 6.27, 0.25 ],
  [4.147, 6.65, 0.25 ],
  [4.147, 7.03, 0.25 ],
  [4.147, 7.41, 0.25 ],
  [4.433, 0.19, 0.25 ],
  [4.433, 0.57, 0.25 ],
  [4.433, 0.95, 0.25 ],
  [4.433, 1.33, 0.25 ],
  [4.433, 1.71, 0.25 ],
  [4.433, 2.09, 0.25 ],
  [4.433, 2.47, 0.25 ],
  [4.433, 2.85, 0.25 ],
  [4.433, 3.23, 0.25 ],
  [4.433, 3.61, 0.25 ],
  [4.433, 3.99, 0.25 ],
  [4.433, 4.37, 0.25 ],
  [4.433, 4.75, 0.25 ],
  [4.433, 5.13, 0.25 ],
  [4.433, 5.51, 0.25 ],
  [4.433, 5.89, 0.25 ],
  [4.433, 6.27, 0.25 ],
  [4.433, 6.65, 0.25 ],
  [4.433, 7.03, 0.25 ],
  [4.433, 7.41, 0.25 ],
  [4.719, 0.19, 0.25 ],
  [4.719, 0.57, 0.25 ],
  [4.719, 0.95, 0.25 ],
  [4.719, 1.33, 0.25 ],
  [4.719, 1.71, 0.25 ],
  [4.719, 2.09, 0.25 ],
  [4.719, 2.47, 0.25 ],
  [4.719, 2.85, 0.25 ],
  [4.719, 3.23, 0.25 ],
  [4.719, 3.61, 0.25 ],
  [4.719, 3.99, 0.25 ],
  [4.719, 4.37, 0.25 ],
  [4.719, 4.75, 0.25 ],
  [4.719, 5.13, 0.25 ],
  [4.719, 5.51, 0.25 ],
  [4.719, 5.89, 0.25 ],
  [4.719, 6.27, 0.25 ],
  [4.719, 6.65, 0.25 ],
  [4.719, 7.03, 0.25 ],
  [4.719, 7.41, 0.25 ],
  [5.005, 0.19, 0.25 ],
  [5.005, 0.57, 0.25 ],
  [5.005, 0.95, 0.25 ],
  [5.005, 1.33, 0.25 ],
  [5.005, 1.71, 0.25 ],
  [5.005, 2.09, 0.25 ],
  [5.005, 2.47, 0.25 ],
  [5.005, 2.85, 0.25 ],
  [5.005, 3.23, 0.25 ],
  [5.005, 3.61, 0.25 ],
  [5.005, 3.99, 0.25 ],
  [5.005, 4.37, 0.25 ],
  [5.005, 4.75, 0.25 ],
  [5.005, 5.13, 0.25 ],
  [5.005, 5.51, 0.25 ],
  [5.005, 5.89, 0.25 ],
  [5.005, 6.27, 0.25 ],
  [5.005, 6.65, 0.25 ],
  [5.005, 7.03, 0.25 ],
  [5.005, 7.41, 0.25 ],
  [5.291, 0.19, 0.25 ],
  [5.291, 0.57, 0.25 ],
  [5.291, 0.95, 0.25 ],
  [5.291, 1.33, 0.25 ],
  [5.291, 1.71, 0.25 ],
  [5.291, 2.09, 0.25 ],
  [5.291, 2.47, 0.25 ],
  [5.291, 2.85, 0.25 ],
  [5.291, 3.23, 0.25 ],
  [5.291, 3.61, 0.25 ],
  [5.291, 3.99, 0.25 ],
  [5.291, 4.37, 0.25 ],
  [5.291, 4.75, 0.25 ],
  [5.291, 5.13, 0.25 ],
  [5.291, 5.51, 0.25 ],
  [5.291, 5.89, 0.25 ],
  [5.291, 6.27, 0.25 ],
  [5.291, 6.65, 0.25 ],
  [5.291, 7.03, 0.25 ],
  [5.291, 7.41, 0.25 ],
  [5.577, 0.19, 0.25 ],
  [5.577, 0.57, 0.25 ],
  [5.577, 0.95, 0.25 ],
  [5.577, 1.33, 0.25 ],
  [5.577, 1.71, 0.25 ],
  [5.577, 2.09, 0.25 ],
  [5.577, 2.47, 0.25 ],
  [5.577, 2.85, 0.25 ],
  [5.577, 3.23, 0.25 ],
  [5.577, 3.61, 0.25 ],
  [5.577, 3.99, 0.25 ],
  [5.577, 4.37, 0.25 ],
  [5.577, 4.75, 0.25 ],
  [5.577, 5.13, 0.25 ],
  [5.577, 5.51, 0.25 ],
  [5.577, 5.89, 0.25 ],
  [5.577, 6.27, 0.25 ],
  [5.577, 6.65, 0.25 ],
  [5.577, 7.03, 0.25 ],
  [5.577, 7.41, 0.25 ]
])

# %%
# print area locations and antenna 
fig = plt.figure()
ax = fig.add_subplot( 131, projection='3d' )
ax.scatter( mems_position2[:,0], mems_position2[:,1], mems_position2[:,2] )
ax.scatter( locations[:,0], locations[:,1], locations[:,2] )
ax = fig.add_subplot( 132, projection='3d' )
ax.scatter( mems_position[:,0], mems_position[:,1], mems_position[:,2] )
ax = fig.add_subplot( 133, projection='3d' )
ax.scatter( mems_position2[:,0], mems_position2[:,1], mems_position2[:,2], c=[i for i in range(32)] )
fig.show()

# %%
signal = np.array( [
1.7424e+06, 1.73984e+06, 1.73058e+06, 1.71019e+06, 1.67519e+06, 1.62729e+06, 1.57468e+06, 1.5263e+06, 1.48652e+06, 1.45552e+06, 1.73229e+06, 1.73092e+06, 1.72297e+06, 1.70249e+06, 1.66351e+06, 1.60772e+06, 1.54773e+06, 1.49603e+06, 1.45658e+06, 1.42773e+06, 1.71718e+06, 1.71588e+06, 1.70827e+06, 1.68701e+06, 1.64299e+06, 1.57784e+06, 1.51102e+06, 1.45866e+06, 1.42226e+06, 1.39747e+06, 1.69632e+06, 1.6931e+06, 1.6834e+06, 1.6589e+06, 1.60784e+06, 1.53318e+06, 1.46323e+06, 1.41503e+06, 1.385e+06, 1.36604e+06, 1.66976e+06, 1.66216e+06, 1.64676e+06, 1.61471e+06, 1.55419e+06, 1.4735e+06, 1.40781e+06, 1.36902e+06, 1.34767e+06, 1.33536e+06, 1.63866e+06, 1.62472e+06, 1.60083e+06, 1.5584e+06, 1.4896e+06, 1.41052e+06, 1.35509e+06, 1.32707e+06, 1.31395e+06, 1.30758e+06, 1.6051e+06, 1.58442e+06, 1.55218e+06, 1.50177e+06, 1.43162e+06, 1.361e+06, 1.31552e+06, 1.29471e+06, 1.28681e+06, 1.28436e+06, 1.57151e+06, 1.54527e+06, 1.5075e+06, 1.45471e+06, 1.38998e+06, 1.32993e+06, 1.29129e+06, 1.2734e+06, 1.26731e+06, 1.26649e+06, 1.53985e+06, 1.51007e+06, 1.47024e+06, 1.41956e+06, 1.36287e+06, 1.31231e+06, 1.27837e+06, 1.26113e+06, 1.25468e+06, 1.25376e+06, 1.51134e+06, 1.48002e+06, 1.44072e+06, 1.39426e+06, 1.34541e+06, 1.30248e+06, 1.27213e+06, 1.25495e+06, 1.24734e+06, 1.24311e+06
])
plt.figure()
plt.plot( signal[0:64] )

# %%
BFE = np.array( [
1816.47, 1868.99, 1899.45, 1915.96, 1925.35, 1931.1, 1934.87, 1937.47, 1939.35, 1940.77, 1774.25, 1828.63, 1865.09, 1887.51, 1901.6, 1910.92, 1917.42, 1922.15, 1925.72, 1928.5, 1742.85, 1794.04, 1832.95, 1859.64, 1877.77, 1890.43, 1899.58, 1906.44, 1911.72, 1915.89, 1721.87, 1767.48, 1805.6, 1834.28, 1855.18, 1870.51, 1881.98, 1890.77, 1897.67, 1903.19, 1708.17, 1747.97, 1783.54, 1812.34, 1834.67, 1851.82, 1865.09, 1875.52, 1883.84, 1890.6, 1699.04, 1733.72, 1766.13, 1793.89, 1816.57, 1834.74, 1849.27, 1860.96, 1870.48, 1878.31, 1692.74, 1723.15, 1752.44, 1778.6, 1800.89, 1819.43, 1834.71, 1847.3, 1857.74, 1866.47, 1688.23, 1715.14, 1741.59, 1765.95, 1787.43, 1805.86, 1821.48, 1834.64, 1845.75, 1855.17, 1684.91, 1708.94, 1732.89, 1755.47, 1775.91, 1793.93, 1809.55, 1823.01, 1834.56, 1844.5, 1682.38, 1704.04, 1725.82, 1746.72, 1766.05, 1783.45, 1798.87, 1812.39, 1824.19, 1834.49
])
BFE = np.reshape( BFE, (10, 10) )
plt.imshow( BFE, origin='lower')
