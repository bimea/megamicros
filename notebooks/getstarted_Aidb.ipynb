# %% [markdown]
# # Getting started with Aidb database tools
#
# ## Set database parameters

# %%
import numpy as np
from pprint import pprint
from megamicros.log import log
from megamicros.aidb.query import AidbSession

log.setLevel( "INFO" )

# Set database access credentials
DBHOST = 'http://dbwelfare.biimea.io/'
LOGIN = 'ailab'
EMAIL = 'bruno.gas@biimea.com'
PASSWORD = '#T;uZnQ5UJ_JC~&'

# %% [markdown]
# ## Get some informations

# %%
with AidbSession(
    dbhost='http://dbwelfare.bimea.tech/',
    login='ailab',
    email='bruno.gas@biimea.com',
    password='#T;uZnQ5UJ_JC~&' ) as session:
        
        domains = session.getDomains()
        print( "domains:" )
        pprint( domains )

        campaigns = session.getCampaigns( domain_id=1 )
        print( "campaigns:" )
        pprint( campaigns )

        devices = session.getDevices()
        print( "devices:" )
        pprint( devices )
# Out:
# 2024-01-29 00:09:27,296 [INFO]:  .Try connecting on endpoint database http://dbwelfare.bimea.tech//dj-rest-auth/login/...
# 2024-01-29 00:09:27,674 [INFO]:  .Got HTTP 200 status code from server
# 2024-01-29 00:09:27,675 [INFO]:  .Received CSRF token: rK5xcx3FUNN31kCpuL134QT3dKxTx0Gx. Update session with
# 2024-01-29 00:09:27,676 [INFO]:  .Received session id: aotbx12eabg5w9qbb5iq9lzymwyezqsg
# 2024-01-29 00:09:27,677 [INFO]:  .Successfully connected on http://dbwelfare.bimea.tech/
# 2024-01-29 00:09:27,678 [INFO]:  .Send a database request on endpoint: http://dbwelfare.bimea.tech//domain/?limit=50
# 2024-01-29 00:09:27,730 [INFO]:  .Send a database request on endpoint: http://dbwelfare.bimea.tech//campaign/?domain=1&limit=50
# 2024-01-29 00:09:27,747 [INFO]:  .Send a database request on endpoint: http://dbwelfare.bimea.tech//device/?limit=50
# 2024-01-29 00:09:27,766 [INFO]:  .Trying to disconnect from database http://dbwelfare.bimea.tech/...
# 2024-01-29 00:09:27,788 [INFO]:  .Logout successful.
# domains:
# [{'id': 1, 'name': 'Bien-être animal et mortalité porcine'},
#  {'id': 2, 'name': 'BTP suivi de chantier'}]
# campaigns:
# [{'date': '2022-06-23', 'id': 1, 'name': 'La Mosellerie - postsevrage'},
#  {'date': '2022-07-19', 'id': 2, 'name': 'Le Préau - naissance et sevrage'}]
# devices:
# [{'id': 1,
#   'identifier': 'Mu32-Mems32-JetsonNano-0001',
#   'name': 'Antenne carrée',
#   'type': 'MemsArray'},
#  {'id': 2,
#   'identifier': 'Mu32-Mems32-Otazak-0002',
#   'name': 'Antenne T',
#   'type': 'MemsArray'},
#  {'id': 3,
#   'identifier': 'CamHD1024p-Logitech-0003',
#   'name': 'Caméra Logitech',
#   'type': 'CamHD1080p'},
#  {'id': 4,
#   'identifier': 'CamHD1024p-Logitech-0004',
#   'name': 'Caméra Logitech',
#   'type': 'CamHD1080p'},
#  {'id': 5,
#   'identifier': 'Mu32-Mems32-MiniPC-0005',
#   'name': 'Antenne carrée étanche',
#   'type': 'MemsArray'}]

# %% [markdown]
# ## Get source files
#
# ### List files in database

# %%
with AidbSession(
    dbhost='http://dbwelfare.bimea.tech/',
    login='ailab',
    email='bruno.gas@biimea.com',
    password='#T;uZnQ5UJ_JC~&' ) as session:

        sourcefiles = session.getSourcefiles()
        print( "sourcefiles:" )
        pprint( sourcefiles )

# %% [markdown]
# ### Informations
#
# The ``AidbSession.getSourcefileInfo()`` method allows you to get detailed informations about an audio file.
# The file reference can be its DB identifier, or its url address, or its file name.

# %%
with AidbSession(
    dbhost='http://dbwelfare.bimea.tech/',
    login='ailab',
    email='bruno.gas@biimea.com',
    password='#T;uZnQ5UJ_JC~&' ) as session:

        fileinfo = session.getSourcefileInfo( id=2 )
        print( "file info:" )
        pprint( fileinfo )     

        fileinfo = session.getSourcefileInfo( url='http://dbwelfare.biimea.io/sourcefile/10/' )
        print( "file info:" )
        pprint( fileinfo )

        fileinfo = session.getSourcefileInfo( filename='mu5h-20220710-225910.h5' )
        print( "file info:" )
        pprint( fileinfo )

# %% [markdown]
# ### Content
#
# The ``downloadSourcefile`` allow to download file content from the database

# %%
with AidbSession(
    dbhost='http://dbwelfare.bimea.tech/',
    login='ailab',
    email='bruno.gas@biimea.com',
    password='#T;uZnQ5UJ_JC~&' ) as session:
        file_info = session.getSourcefileInfo( id=2 )
        file_content = session.downloadSourcefile( id=2 )

        h5filename = file_info['H5 filename']
        print( f"save {h5filename} file" )
        with open( h5filename, 'bw' ) as file:
            file.write( file_content )

        file_content = session.downloadSourcefile( id=2, as_wav=True )
        wavfilename = file_info['WAV filename'].replace(".h5", ".wav")
        print( f"save {wavfilename} file" )
        with open( wavfilename, 'bw' ) as file:
            file.write( file_content )
# Out:
# 2024-01-29 00:09:54,492 [INFO]:  .Try connecting on endpoint database http://dbwelfare.bimea.tech//dj-rest-auth/login/...
# 2024-01-29 00:09:54,971 [INFO]:  .Got HTTP 200 status code from server
# 2024-01-29 00:09:54,972 [INFO]:  .Received CSRF token: 4oOCOSScymEDVMyzrrxLaz0kiYVmRTNN. Update session with
# 2024-01-29 00:09:54,973 [INFO]:  .Received session id: m5jhbosyi7rlwhwc01447szrf4xgzwat
# 2024-01-29 00:09:54,974 [INFO]:  .Successfully connected on http://dbwelfare.bimea.tech/
# 2024-01-29 00:09:54,975 [INFO]:  .Send a database request on endpoint: http://dbwelfare.bimea.tech//sourcefile/2
# 2024-01-29 00:09:55,015 [INFO]:  .Send a database request on endpoint: http://dbwelfare.bimea.tech//sourcefile/2/download/
# 2024-01-29 00:13:00,621 [INFO]:  .Trying to disconnect from database http://dbwelfare.bimea.tech/...
# 2024-01-29 00:13:00,681 [INFO]:  .Logout successful.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 7
#       1 with AidbSession(
#       2     dbhost='http://dbwelfare.bimea.tech/',
#       3     login='ailab',
#       4     email='bruno.gas@biimea.com',
#       5     password='#T;uZnQ5UJ_JC~&' ) as session:
#       6         file_info = session.getSourcefileInfo( id=2 )
# ----> 7         file_content = session.downloadSourcefile( id=2 )
#       9         h5filename = file_info['H5 filename']
#      10         print( f"save {h5filename} file" )
#
# File ~/Documents/Dev/Bimea/megamicros/notebooks/megamicros/aidb/query.py:267, in AidbSession.downloadSourcefile(self, id, as_wav)
#     265         response = self.get( f'/sourcefile/{id}/download_as_wav' ).content
#     266     else:
# --> 267         response = self.get( f'/sourcefile/{id}/download/' ).content
#     269 except MuDbException as e:
#     270     log.info( f" .{e}" )
#
# File ~/Documents/Dev/Bimea/megamicros/notebooks/megamicros/aidb/session.py:260, in RestDBSession.get(self, request, timeout, full_url)
#     257     request = f"{self.__dbhost}{request}"
#     259 log.info( f" .Send a database request on endpoint: {request}" )
# --> 260 response  = self.session.get( request, timeout=timeout )
#     261 if not response.ok:
#     262     log.warning( f"[GET] request failed on database '{self.__dbhost}' with status code: {response.status_code}" )
#
# File ~/Documents/Dev/Bimea/megamicros/venv/lib/python3.10/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~/Documents/Dev/Bimea/megamicros/venv/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Documents/Dev/Bimea/megamicros/venv/lib/python3.10/site-packages/requests/sessions.py:747, in Session.send(self, request, **kwargs)
#     744         pass
#     746 if not stream:
# --> 747     r.content
#     749 return r
#
# File ~/Documents/Dev/Bimea/megamicros/venv/lib/python3.10/site-packages/requests/models.py:899, in Response.content(self)
#     897         self._content = None
#     898     else:
# --> 899         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     901 self._content_consumed = True
#     902 # don't need to release the connection; that's been handled by urllib3
#     903 # since we exhausted the data.
#
# File ~/Documents/Dev/Bimea/megamicros/venv/lib/python3.10/site-packages/requests/models.py:816, in Response.iter_content.<locals>.generate()
#     814 if hasattr(self.raw, "stream"):
#     815     try:
# --> 816         yield from self.raw.stream(chunk_size, decode_content=True)
#     817     except ProtocolError as e:
#     818         raise ChunkedEncodingError(e)
#
# File ~/Documents/Dev/Bimea/megamicros/venv/lib/python3.10/site-packages/urllib3/response.py:940, in HTTPResponse.stream(self, amt, decode_content)
#     938 else:
#     939     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
# --> 940         data = self.read(amt=amt, decode_content=decode_content)
#     942         if data:
#     943             yield data
#
# File ~/Documents/Dev/Bimea/megamicros/venv/lib/python3.10/site-packages/urllib3/response.py:879, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     876     if len(self._decoded_buffer) >= amt:
#     877         return self._decoded_buffer.get(amt)
# --> 879 data = self._raw_read(amt)
#     881 flush_decoder = False
#     882 if amt is None:
#
# File ~/Documents/Dev/Bimea/megamicros/venv/lib/python3.10/site-packages/urllib3/response.py:814, in HTTPResponse._raw_read(self, amt)
#     811 fp_closed = getattr(self._fp, "closed", False)
#     813 with self._error_catcher():
# --> 814     data = self._fp_read(amt) if not fp_closed else b""
#     815     if amt is not None and amt != 0 and not data:
#     816         # Platform-specific: Buggy versions of Python.
#     817         # Close the connection when no data is returned
#    (...)
#     822         # not properly close the connection in all cases. There is
#     823         # no harm in redundantly calling close.
#     824         self._fp.close()
#
# File ~/Documents/Dev/Bimea/megamicros/venv/lib/python3.10/site-packages/urllib3/response.py:799, in HTTPResponse._fp_read(self, amt)
#     796     return buffer.getvalue()
#     797 else:
#     798     # StringIO doesn't like amt=None
# --> 799     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:465, in HTTPResponse.read(self, amt)
#     462 if self.length is not None and amt > self.length:
#     463     # clip the read to the "end of response"
#     464     amt = self.length
# --> 465 s = self.fp.read(amt)
#     466 if not s and amt:
#     467     # Ideally, we would raise IncompleteRead if the content-length
#     468     # wasn't satisfied, but it might break compatibility.
#     469     self._close_conn()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# KeyboardInterrupt:
