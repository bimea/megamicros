# %% [markdown]
# # Getting started with Aidb database tools
#
# ## Set database parameters and get some informations

# %%
import numpy as np
from pprint import pprint
from megamicros.log import log
from megamicros.aidb.query import AidbSession

log.setLevel( "INFO" )

# Set database access credentials
DBHOST = 'http://dbwelfare.biimea.io/'
LOGIN = 'ailab'
EMAIL = 'bruno.gas@biimea.com'
PASSWORD = '#T;uZnQ5UJ_JC~&'

with AidbSession(
    dbhost='http://dbwelfare.biimea.io/',
    login='ailab',
    email='bruno.gas@biimea.com',
    password='#T;uZnQ5UJ_JC~&' ) as session:
        
        domains = session.getDomains()
        print( "domains:" )
        pprint( domains )

        campaigns = session.getCampaigns( domain_id=1 )
        print( "campaigns:" )
        pprint( campaigns )

        devices = session.getDevices()
        print( "devices:" )
        pprint( devices )
# Out:
# 2023-09-25 23:22:27,898 [INFO]:  .Try connecting on endpoint database http://dbwelfare.biimea.io/...
# 2023-09-25 23:22:28,359 [INFO]:  .Got HTTP 200 status code from server
# 2023-09-25 23:22:28,359 [INFO]:  .Received CSRF token: ucZgFdxxdA3o7qIp9of8HUMJmv5gYD4x. Update session with
# 2023-09-25 23:22:28,360 [INFO]:  .Received session id: 2429nxxt9iiofkapnlmx78gwqgqhpq80
# 2023-09-25 23:22:28,361 [INFO]:  .Successfully connected on http://dbwelfare.biimea.io/
# 2023-09-25 23:22:28,443 [INFO]:  .Trying to disconnect from database http://dbwelfare.biimea.io/...
# 2023-09-25 23:22:28,463 [INFO]:  .Logout successful.
# domains:
# [{'id': 1, 'name': 'Bien-être animal et mortalité porcine'},
#  {'id': 2, 'name': 'BTP suivi de chantier'}]
# campaigns:
# [{'date': '2022-06-23', 'id': 1, 'name': 'La Mosellerie - postsevrage'},
#  {'date': '2022-07-19', 'id': 2, 'name': 'Le Préau - naissance et sevrage'}]
# devices:
# [{'id': 1,
#   'identifier': 'Mu32-Mems32-JetsonNano-0001',
#   'name': 'Antenne carrée',
#   'type': 'MemsArray'},
#  {'id': 2,
#   'identifier': 'Mu32-Mems32-Otazak-0002',
#   'name': 'Antenne T',
#   'type': 'MemsArray'},
#  {'id': 3,
#   'identifier': 'CamHD1024p-Logitech-0003',
#   'name': 'Caméra Logitech',
#   'type': 'CamHD1080p'},
#  {'id': 4,
#   'identifier': 'CamHD1024p-Logitech-0004',
#   'name': 'Caméra Logitech',
#   'type': 'CamHD1080p'},
#  {'id': 5,
#   'identifier': 'Mu32-Mems32-MiniPC-0005',
#   'name': 'Antenne carrée étanche',
#   'type': 'MemsArray'}]

# %% [markdown]
# ## Getting source files

# %%
with AidbSession(
    dbhost='http://dbwelfare.biimea.io/',
    login='ailab',
    email='bruno.gas@biimea.com',
    password='#T;uZnQ5UJ_JC~&' ) as session:

        sourcefiles = session.getSourcefiles()
        print( "sourcefiles:" )
        pprint( sourcefiles )
# Out:
# 2023-09-25 23:22:32,012 [INFO]:  .Try connecting on endpoint database http://dbwelfare.biimea.io/...
# 2023-09-25 23:22:32,346 [INFO]:  .Got HTTP 200 status code from server
# 2023-09-25 23:22:32,347 [INFO]:  .Received CSRF token: nbF1kswnAkxdhJsFPOuOpESrB08p4O9K. Update session with
# 2023-09-25 23:22:32,348 [INFO]:  .Received session id: 7az5un3ye5pznfle2vo65buj015i0d07
# 2023-09-25 23:22:32,350 [INFO]:  .Successfully connected on http://dbwelfare.biimea.io/
# 2023-09-25 23:22:32,422 [INFO]:  .Trying to disconnect from database http://dbwelfare.biimea.io/...
# 2023-09-25 23:22:32,442 [INFO]:  .Logout successful.
# sourcefiles:
# {'content': [{'datetime': '2022-07-17T01:23:29.497565Z',
#               'duration': 900,
#               'filename': 'mu5h-20220717-012329.h5',
#               'id': 1,
#               'type': 4},
#              {'datetime': '2022-07-10T22:59:10.765893Z',
#               'duration': 900,
#               'filename': 'mu5h-20220710-225910.h5',
#               'id': 2,
#               'type': 4},
#              {'datetime': '2022-06-27T05:43:20.180710Z',
#               'duration': 900,
#               'filename': 'mu5h-20220627-054320.h5',
#               'id': 3,
#               'type': 4},
#              {'datetime': '2022-06-30T21:55:28.324995Z',
#               'duration': 900,
#               'filename': 'mu5h-20220630-215528.h5',
#               'id': 4,
#               'type': 4},
#              {'datetime': '2022-07-15T02:27:43.578510Z',
#               'duration': 900,
#               'filename': 'mu5h-20220715-022743.h5',
#               'id': 5,
#               'type': 4},
#              {'datetime': '2022-06-30T06:48:20.372416Z',
#               'duration': 900,
#               'filename': 'mu5h-20220630-064820.h5',
#               'id': 6,
#               'type': 4},
#              {'datetime': '2022-07-12T07:32:41.670097Z',
#               'duration': 600,
#               'filename': 'mu5h-20220712-073241.h5',
#               'id': 7,
#               'type': 4},
#              {'datetime': '2022-07-02T07:59:37.412606Z',
#               'duration': 900,
#               'filename': 'mu5h-20220702-075937.h5',
#               'id': 8,
#               'type': 4},
#              {'datetime': '2022-07-06T20:24:39.056554Z',
#               'duration': 900,
#               'filename': 'mu5h-20220706-202439.h5',
#               'id': 9,
#               'type': 4},
#              {'datetime': '2022-06-30T16:37:37.228431Z',
#               'duration': 900,
#               'filename': 'mu5h-20220630-163737.h5',
#               'id': 10,
#               'type': 4},
#              {'datetime': '2022-06-26T22:08:56.060872Z',
#               'duration': 900,
#               'filename': 'mu5h-20220626-220856.h5',
#               'id': 11,
#               'type': 4},
#              {'datetime': '2022-06-27T14:49:14.140424Z',
#               'duration': 900,
#               'filename': 'mu5h-20220627-144914.h5',
#               'id': 12,
#               'type': 4},
#              {'datetime': '2022-07-17T15:02:51.607539Z',
#               'duration': 900,
#               'filename': 'mu5h-20220717-150251.h5',
#               'id': 13,
#               'type': 4},
#              {'datetime': '2022-07-11T02:15:32.981839Z',
#               'duration': 600,
#               'filename': 'mu5h-20220711-021532.h5',
#               'id': 14,
#               'type': 4},
#              {'datetime': '2022-07-11T19:41:06.547855Z',
#               'duration': 900,
#               'filename': 'mu5h-20220711-194106.h5',
#               'id': 15,
#               'type': 4},
#              {'datetime': '2022-07-10T11:06:38.934310Z',
#               'duration': 600,
#               'filename': 'mu5h-20220710-110638.h5',
#               'id': 16,
#               'type': 4},
#              {'datetime': '2022-07-02T14:17:38.501383Z',
#               'duration': 900,
#               'filename': 'mu5h-20220702-141738.h5',
#               'id': 17,
#               'type': 4},
#              {'datetime': '2022-07-04T03:56:01.260333Z',
#               'duration': 900,
#               'filename': 'mu5h-20220704-035601.h5',
#               'id': 18,
#               'type': 4},
#              {'datetime': '2022-07-12T01:13:24.086382Z',
#               'duration': 900,
#               'filename': 'mu5h-20220712-011324.h5',
#               'id': 19,
#               'type': 4},
#              {'datetime': '2022-07-13T06:17:07.564186Z',
#               'duration': 900,
#               'filename': 'mu5h-20220713-061707.h5',
#               'id': 20,
#               'type': 4}],
#  'count': 18477}
