# %% [markdown]
# # Get started with Megamicros USB devices
#
# This Notebook is devoted to low level megamicros devices access

# %%
from megamicros.log import log
from megamicros.usb import Usb
# set log level to INFO to get more information (available levels are DEBUG, INFO, WARNING, ERROR, FATAL)
log.setLevel( "INFO" ) 

usb = Usb( vendor_id=0xFE27, product_id=0xAC03, bus_address=0x00, endpoint_in=0x81 )
usb.close()
# Out:
# 2025-10-21 09:28:39,600 [INFO]:  .Connecting to USB device fe27:ac03 ...
# ---------------------------------------------------------------------------
# UsbException                              Traceback (most recent call last)
# Cell In[1], line 6
#       3 # set log level to INFO to get more information (available levels are DEBUG, INFO, WARNING, ERROR, FATAL)
#       4 log.setLevel( "INFO" )
# ----> 6 usb = Usb( vendor_id=0xFE27, product_id=0xAC03, bus_address=0x00, endpoint_in=0x81 )
#       7 usb.close()
#
# File ~/Documents/Dev/Bimea/megamicros-3.0.0/src/megamicros/usb.py:55, in Usb.__init__(self, vendor_id, product_id, bus_address, endpoint_in, endpoint_out)
#      52 self.__is_claimed = False
#      54 if vendor_id is not None and product_id is not None and bus_address is not None :
# ---> 55     self.open( vendor_id, product_id, bus_address, endpoint_in if endpoint_in is not None else USB_DEFAULT_ENDPOINT_IN, endpoint_out )
#
# File ~/Documents/Dev/Bimea/megamicros-3.0.0/src/megamicros/usb.py:73, in Usb.open(self, vendor_id, product_id, bus_address, endpoint_in, endpoint_out)
#      66 self.__usb_handle = self.__context.openByVendorIDAndProductID(
#      67     vendor_id,
#      68     product_id,
#      69     skip_on_error=True,
#      70 )
#      72 if self.__usb_handle is None:
# ---> 73     raise UsbException( 'Failed to connect to USB device: the device may be disconnected or user not allowed to access' )
#      75 # Test claiming the interface:
#      76 self.claim()
#
# UsbException: Failed to connect to USB device: the device may be disconnected or user not allowed to access
