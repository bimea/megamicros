# %% [markdown]
# # Get started with Megamicros USB devices
#
# This Notebook is devoted to low level megamicros devices access

# %%
from megamicros.log import log
from megamicros.usb import Usb
# set log level to INFO to get more information (available levels are DEBUG, INFO, WARNING, ERROR, FATAL)
log.setLevel( "INFO" ) 

usb = Usb( vendor_id=0xFE27, product_id=0xAC03, bus_address=0x00, endpoint_in=0x81 )
usb.close()
# Out:
# 2025-10-22 00:17:11,535 [INFO]:  .Connecting to USB device fe27:ac03 ...
# 2025-10-22 00:17:11,545 [INFO]:  .Claimed interface 0 on USB device fe27:ac03
# 2025-10-22 00:17:11,545 [INFO]:  .Released interface 0 on USB device fe27:ac03
# 2025-10-22 00:17:11,546 [INFO]:  .Connected on USB device fe27:ac03
# 2025-10-22 00:17:11,547 [INFO]:  .Disconnected from USB device fe27:ac03

# %%
from megamicros.megamicros import Megamicros

megamicros = Megamicros()

print( "Available MEMS: ", megamicros.available_mems )
print( "Available Analogs: ", megamicros.available_analogs )
# Out:
# 2025-10-22 00:17:11,603 [INFO]:  .Connecting to USB device fe27:ac03 ...
# 2025-10-22 00:17:11,604 [INFO]:  .Claimed interface 0 on USB device fe27:ac03
# 2025-10-22 00:17:11,604 [INFO]:  .Released interface 0 on USB device fe27:ac03
# 2025-10-22 00:17:11,604 [INFO]:  .Connected on USB device fe27:ac03
# 2025-10-22 00:17:11,605 [INFO]:  .Performing selftest using bulk read method...
# 2025-10-22 00:17:11,605 [INFO]:  .Claimed interface 0 on USB device fe27:ac03
# 2025-10-22 00:17:11,975 [INFO]:  .Selftest completed successfully
# 2025-10-22 00:17:11,976 [INFO]:  .Released interface 0 on USB device fe27:ac03
# 2025-10-22 00:17:11,977 [INFO]:  .Autotest results:
# 2025-10-22 00:17:11,977 [INFO]:   > equivalent recording time is: 0.1
# 2025-10-22 00:17:11,978 [INFO]:   > Received 633600 data bytes: 4400 samples on 36 channels
# 2025-10-22 00:17:11,978 [INFO]:   > detected 8 active MEMs: [0, 1, 2, 3, 4, 5, 6, 7]
# 2025-10-22 00:17:11,979 [INFO]:   > detected 0 active analogs: []
# 2025-10-22 00:17:11,979 [INFO]:   > detected counter channel with values from 10663 to 15062
# 2025-10-22 00:17:11,980 [INFO]:   > estimated data lost: 0 samples
# 2025-10-22 00:17:11,980 [INFO]:   > detected status channel with values 0 <-> 16
# 2025-10-22 00:17:11,980 [INFO]:  .Selftest endded successfully
# 2025-10-22 00:17:11,980 [INFO]:  .Megamicros device initialized
# Available MEMS:  [0, 1, 2, 3, 4, 5, 6, 7]
# Available Analogs:  []
