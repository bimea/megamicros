# %% [markdown]
# # Get started with Megamicros USB devices
#
# This Notebook is devoted to low level megamicros devices access

# %%
from megamicros.log import log
from megamicros.usb import Usb
# set log level to INFO to get more information (available levels are DEBUG, INFO, WARNING, ERROR, FATAL)
log.setLevel( "INFO" ) 

usb = Usb( vendor_id=0xFE27, product_id=0xAC03, bus_address=0x00, endpoint_in=0x81 )
usb.close()
# Out:
# 2025-10-21 19:18:39,068 [INFO]:  .Connecting to USB device fe27:ac03 ...
# 2025-10-21 19:18:39,078 [INFO]:  .Claimed interface 0 on USB device fe27:ac03
# 2025-10-21 19:18:39,079 [INFO]:  .Connected on USB device fe27:ac03
# 2025-10-21 19:18:39,080 [INFO]:  .Disconnected from USB device fe27:ac03

# %%
from megamicros.megamicros import Megamicros

megamicros = Megamicros()
# Out:
# 2025-10-21 19:18:40,689 [INFO]:  .Connecting to USB device fe27:ac00 ...
# 2025-10-21 19:18:40,693 [INFO]:  .Connecting to USB device fe27:ac03 ...
# 2025-10-21 19:18:40,694 [INFO]:  .Connecting to USB device fe27:ac03 ...
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# Cell In[2], line 3
#       1 from megamicros.megamicros import Megamicros
# ----> 3 megamicros = Megamicros()
#
# File ~/Documents/Dev/Bimea/megamicros-3.0.0/src/megamicros/megamicros.py:154, in Megamicros.__init__(self)
#     151 self.__sync_delay: int=10                                     # Default synchronization delay (10 for usual systems, 8 for Aikhous systems)
#     152 self.__wait_delay: int=0                                      # Wait delay between start command and
# --> 154 self.checkAndOpenDevice()
#     155 log.info(" .Megamicros device initialized")
#
# File ~/Documents/Dev/Bimea/megamicros-3.0.0/src/megamicros/megamicros.py:178, in Megamicros.checkAndOpenDevice(self)
#     176     self.__clock_divider_reference = DEFAULT_CLOCK_DIVIDER_REFERENCE
#     177     self.__sync_delay = DEFAULT_SYNC_DELAY
# --> 178     self.__usb.open(MU32_USB3_VENDOR_ID, MU32_USB3_VENDOR_PRODUCT, MU_BUS_ADDRESS, MU32_USB3_ENDPOINT_IN)
#     180 elif self.__usb.checkDeviceByVendorProduct(MU256_USB3_VENDOR_ID, MU256_USB3_VENDOR_PRODUCT):
#     181     self.__pluggable_beams_number = MU256_USB3_PLUGGABLE_BEAMS_NUMBER
#
# File ~/Documents/Dev/Bimea/megamicros-3.0.0/src/megamicros/usb.py:234, in Usb.open(self, vendor_id, product_id, bus_address, endpoint_in, endpoint_out)
#     231     raise UsbException( 'Failed to connect to USB device: the device may be disconnected or user not allowed to access' )
#     233 # Test claiming the interface:
# --> 234 self.claim()
#     236 self.__vendor_id = vendor_id
#     237 self.__product_id = product_id
#
# File ~/Documents/Dev/Bimea/megamicros-3.0.0/src/megamicros/usb.py:253, in Usb.claim(self)
#     251 if self.__is_claimed == False:
#     252     if self.__usb_handle is not None:
# --> 253         if self.__usb_handle.claimInterface( self.__bus_address ) == False:
#     254             raise UsbException( f'Failed to claim interface {self.__bus_address} on USB device {self.__vendor_id:04x}:{self.__product_id:04x}' )
#     255         log.info( f' .Claimed interface {self.__bus_address} on USB device {self.__vendor_id:04x}:{self.__product_id:04x}' )
#
# File ~/Documents/Dev/Bimea/megamicros-3.0.0/venv/lib/python3.12/site-packages/usb1/__init__.py:1223, in USBDeviceHandle.claimInterface(self, interface)
#    1212 def claimInterface(self, interface):
#    1213     """
#    1214     Claim (= get exclusive access to) given interface number. Required to
#    1215     receive/send data.
#    (...)   1220         # handle.releaseInterface(0) gets automatically called
#    1221     """
#    1222     mayRaiseUSBError(
# -> 1223         libusb1.libusb_claim_interface(self.__handle, interface),
#    1224     )
#    1225     return _ReleaseInterface(self, interface)
#
# ArgumentError: argument 2: TypeError: 'NoneType' object cannot be interpreted as an integer
