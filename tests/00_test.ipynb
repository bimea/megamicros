# %%
from megamicros import Megamicros
import numpy as np
from megamicros.log import log

log.setLevel("INFO")

antenna = Megamicros()

# Acquisition de 1 secondes
antenna.run(
    mems=list(range(32)),  # Tous les MEMS
    sampling_frequency=50000,
    duration=1,
    frame_length=1024
)

antenna.wait()

print(f"Queue content before: {antenna.queue_content}")

# Stocker toutes les données
all_frames = []
for frame in antenna:
    all_frames.append(frame)

print(f"Retrieved frames {len(all_frames)}")
print(f"Queue content after: {antenna.queue_content}")

# Concaténer
signal = np.concatenate(all_frames, axis=1)
print(f"Signal complet : {signal.shape}")

# Affiche le compteur en voie 0:
print(f"Compteur en voie 0 : {signal[0, :]}")
# Out:
# 2026-06-29 15:46:37,127 [INFO]: Creating UsbDataSource (0xfe27:0xac03)
# 2026-06-29 15:46:37,128 [INFO]: UsbDataSource initialized: 32 MEMS available
# 2026-06-29 15:46:37,128 [INFO]: Connecting to USB device fe27:ac03 ...
# 2026-06-29 15:46:37,129 [INFO]: Connected on USB device fe27:ac03
# 2026-06-29 15:46:37,130 [INFO]: USB configured: 135168 bytes/frame, 33 channels, 8 buffers
# 2026-06-29 15:46:37,131 [INFO]: RESET and PURGE commands sent to FPGA
# 2026-06-29 15:46:37,131 [INFO]: Sampling frequency 50000Hz sent as clockdiv 9 (nearest activated frequency is 50000Hz)
# 2026-06-29 15:46:37,133 [INFO]: Active channels sent to FPGA: MEMS=32, Analogs=0, Counter=1, Status=False
# 2026-06-29 15:46:37,133 [INFO]: Datatype sent to FPGA: int32
# 2026-06-29 15:46:37,134 [INFO]: Sample count sent to FPGA: 0 (streaming mode if 0)
# 2026-06-29 15:46:37,337 [INFO]: Starting USB acquisition...
# 2026-06-29 15:46:37,339 [INFO]: START command sent to FPGA (trigger: soft, mode: N/A)
# 2026-06-29 15:46:37,339 [INFO]: Starting native USB async bulk transfer (duration=1s, expected frames=49)
# 2026-06-29 15:46:37,340 [INFO]: Init asynchronous bulk transfer...
# 2026-06-29 15:46:37,340 [INFO]: Starting asynchronous bulk transfer thread...
# 2026-06-29 15:46:37,341 [INFO]: (Async bulk THREAD) Transfer thread execution started
# 2026-06-29 15:46:37,341 [INFO]: Acquisition started: 32 MEMS, 50000Hz, 1s duration, 1024 samples/frame
# 2026-06-29 15:46:37,342 [INFO]: Waiting for asynchronous bulk transfer to end...
# 2026-06-29 15:46:38,344 [INFO]: STOP command sent to FPGA (trigger: soft, mode: N/A)
# 2026-06-29 15:46:38,348 [INFO]: USB callback: transfer cancelled
# 2026-06-29 15:46:38,349 [INFO]: USB callback: transfer cancelled
# 2026-06-29 15:46:38,350 [INFO]: USB callback: transfer cancelled
# 2026-06-29 15:46:38,350 [INFO]: USB callback: transfer cancelled
# 2026-06-29 15:46:38,351 [INFO]: USB callback: transfer cancelled
# 2026-06-29 15:46:38,351 [INFO]: USB callback: transfer cancelled
# 2026-06-29 15:46:38,352 [INFO]: USB callback: transfer cancelled
# 2026-06-29 15:46:38,353 [INFO]: USB callback: transfer cancelled
# 2026-06-29 15:46:38,353 [INFO]: (Async bulk THREAD) Quitting transfer loop due to end of process request...
# Queue content before: 49
# Retrieved frames 49
# Queue content after: 0
# Signal complet : (33, 50176)
# Compteur en voie 0 : [10367 10368 10369 ... 60540 60541 60542]
